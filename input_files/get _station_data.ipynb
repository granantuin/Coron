# %% [markdown]
# **speed average**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df_2018 = pd.read_excel("/content/spd_o_2018.xlsx")
df_2019 = pd.read_excel("/content/spd_o_2019.xlsx")
df_2020 = pd.read_excel("/content/spd_o_2020.xlsx")
df_2021 = pd.read_excel("/content/spd_o_2021.xlsx")
df_2022 = pd.read_excel("/content/spd_o_2022.xlsx")

# %%
df_spd_o =pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022])
df_spd_o
# Out:
#                         time  spd_o
# 0      2018-01-01 00:10:00.0   17.3
# 1      2018-01-01 00:20:00.0   16.5
# 2      2018-01-01 00:30:00.0   16.9
# 3      2018-01-01 00:40:00.0   17.1
# 4      2018-01-01 00:50:00.0   18.0
# ...                      ...    ...
# 52411  2022-12-30 23:20:00.0   40.3
# 52412  2022-12-30 23:30:00.0   42.7
# 52413  2022-12-30 23:40:00.0   36.7
# 52414  2022-12-30 23:50:00.0   39.0
# 52415  2022-12-31 00:00:00.0   35.8
#
# [262224 rows x 2 columns]

# %%
df_spd_o["spd_o"] = df_spd_o["spd_o"] *0.277778

# %%
df_spd_o
# Out:
#                         time      spd_o
# 0      2018-01-01 00:10:00.0   4.805559
# 1      2018-01-01 00:20:00.0   4.583337
# 2      2018-01-01 00:30:00.0   4.694448
# 3      2018-01-01 00:40:00.0   4.750004
# 4      2018-01-01 00:50:00.0   5.000004
# ...                      ...        ...
# 52411  2022-12-30 23:20:00.0  11.194453
# 52412  2022-12-30 23:30:00.0  11.861121
# 52413  2022-12-30 23:40:00.0  10.194453
# 52414  2022-12-30 23:50:00.0  10.833342
# 52415  2022-12-31 00:00:00.0   9.944452
#
# [262224 rows x 2 columns]

# %%
df_spd_o.to_csv("spd_o.csv")

# %% [markdown]
# **Gust**

# %%
df_2018 = pd.read_excel("/content/gust_o_2018.xlsx")
df_2019 = pd.read_excel("/content/gust_o_2019.xlsx")
df_2020 = pd.read_excel("/content/gust_o_2020.xlsx")
df_2021 = pd.read_excel("/content/gust_o_2021.xlsx")
df_2022 = pd.read_excel("/content/gust_o_2022.xlsx")

# %%
df_gust_o =pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022])
df_gust_o
# Out:
#                         time  gust_o
# 0      2018-01-01 00:10:00.0    24.0
# 1      2018-01-01 00:20:00.0    22.1
# 2      2018-01-01 00:30:00.0    26.9
# 3      2018-01-01 00:40:00.0    24.6
# 4      2018-01-01 00:50:00.0    26.4
# ...                      ...     ...
# 52411  2022-12-30 23:20:00.0    68.1
# 52412  2022-12-30 23:30:00.0    69.2
# 52413  2022-12-30 23:40:00.0    63.6
# 52414  2022-12-30 23:50:00.0    64.0
# 52415  2022-12-31 00:00:00.0    56.9
#
# [262224 rows x 2 columns]

# %%
df_gust_o["gust_o"] = df_gust_o["gust_o"] *0.277778

# %%
df_gust_o
# Out:
#                         time     gust_o
# 0      2018-01-01 00:10:00.0   6.666672
# 1      2018-01-01 00:20:00.0   6.138894
# 2      2018-01-01 00:30:00.0   7.472228
# 3      2018-01-01 00:40:00.0   6.833339
# 4      2018-01-01 00:50:00.0   7.333339
# ...                      ...        ...
# 52411  2022-12-30 23:20:00.0  18.916682
# 52412  2022-12-30 23:30:00.0  19.222238
# 52413  2022-12-30 23:40:00.0  17.666681
# 52414  2022-12-30 23:50:00.0  17.777792
# 52415  2022-12-31 00:00:00.0  15.805568
#
# [262224 rows x 2 columns]

# %%
df_gust_o.to_csv("gust_o.csv")

# %% [markdown]
# **Dir**

# %%
df_2018 = pd.read_excel("/content/dir_o_2018.xlsx")
df_2019 = pd.read_excel("/content/dir_o_2019.xlsx")
df_2020 = pd.read_excel("/content/dir_o_2020.xlsx")
df_2021 = pd.read_excel("/content/dir_o_2021.xlsx")
df_2022 = pd.read_excel("/content/dir_o_2022.xlsx")

# %%
df_dir_o =pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022])
df_dir_o
# Out:
#                         time  dir_o
# 0      2018-01-01 00:10:00.0  200.0
# 1      2018-01-01 00:20:00.0  198.0
# 2      2018-01-01 00:30:00.0  198.0
# 3      2018-01-01 00:40:00.0  197.0
# 4      2018-01-01 00:50:00.0  199.0
# ...                      ...    ...
# 52411  2022-12-30 23:20:00.0  200.0
# 52412  2022-12-30 23:30:00.0  200.0
# 52413  2022-12-30 23:40:00.0  201.0
# 52414  2022-12-30 23:50:00.0  204.0
# 52415  2022-12-31 00:00:00.0  204.0
#
# [262224 rows x 2 columns]

# %%
df_dir_o.to_csv("dir_o.csv")

# %% [markdown]
# **sddir**

# %%
df_2018 = pd.read_excel("/content/sddir_o_2018.xlsx")
df_2019 = pd.read_excel("/content/sddir_o_2019.xlsx")
df_2020 = pd.read_excel("/content/sddir_o_2020.xlsx")
df_2021 = pd.read_excel("/content/sddir_o_2021.xlsx")
df_2022 = pd.read_excel("/content/sddir_o_2022.xlsx")

# %%
df_sddir_o =pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022])
df_sddir_o
# Out:
#                         time  sddir_o
# 0      2018-01-01 00:10:00.0     10.0
# 1      2018-01-01 00:20:00.0      9.0
# 2      2018-01-01 00:30:00.0     11.0
# 3      2018-01-01 00:40:00.0     11.0
# 4      2018-01-01 00:50:00.0     13.0
# ...                      ...      ...
# 52411  2022-12-30 23:20:00.0     17.0
# 52412  2022-12-30 23:30:00.0     18.0
# 52413  2022-12-30 23:40:00.0     19.0
# 52414  2022-12-30 23:50:00.0     17.0
# 52415  2022-12-31 00:00:00.0     20.0
#
# [262224 rows x 2 columns]

# %%
df_sddir_o.to_csv("sddir_o.csv")

# %% [markdown]
# **sdspd**

# %%
df_2018 = pd.read_excel("/content/sdspd_o_2018.xlsx")
df_2019 = pd.read_excel("/content/sdspd_o_2019.xlsx")
df_2020 = pd.read_excel("/content/sdspd_o_2020.xlsx")
df_2021 = pd.read_excel("/content/sdspd_o_2021.xlsx")
df_2022 = pd.read_excel("/content/sdspd_o_2022.xlsx")

# %%
df_sdspd_o =pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022])
df_sdspd_o
# Out:
#                         time  sdspd_o
# 0      2018-01-01 00:10:00.0      3.0
# 1      2018-01-01 00:20:00.0      2.5
# 2      2018-01-01 00:30:00.0      3.4
# 3      2018-01-01 00:40:00.0      3.6
# 4      2018-01-01 00:50:00.0      3.7
# ...                      ...      ...
# 52411  2022-12-30 23:20:00.0     11.7
# 52412  2022-12-30 23:30:00.0     11.7
# 52413  2022-12-30 23:40:00.0     10.8
# 52414  2022-12-30 23:50:00.0     11.3
# 52415  2022-12-31 00:00:00.0     11.2
#
# [262224 rows x 2 columns]

# %%
df_sdspd_o["sdspd_o"] = df_sdspd_o["sdspd_o"] *0.277778
df_sdspd_o
# Out:
#                         time   sdspd_o
# 0      2018-01-01 00:10:00.0  0.833334
# 1      2018-01-01 00:20:00.0  0.694445
# 2      2018-01-01 00:30:00.0  0.944445
# 3      2018-01-01 00:40:00.0  1.000001
# 4      2018-01-01 00:50:00.0  1.027779
# ...                      ...       ...
# 52411  2022-12-30 23:20:00.0  3.250003
# 52412  2022-12-30 23:30:00.0  3.250003
# 52413  2022-12-30 23:40:00.0  3.000002
# 52414  2022-12-30 23:50:00.0  3.138891
# 52415  2022-12-31 00:00:00.0  3.111114
#
# [262224 rows x 2 columns]

# %%
df_sdspd_o.to_csv("sdspd_o.csv")

# %% [markdown]
# **set up all variables**

# %%
dir_o = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/dir_o.csv").set_index("time")
spd_o = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/spd_o.csv").set_index("time")
gust_o = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/gust_o.csv").set_index("time")
sddir_o = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/sddir_o.csv").set_index("time")
sdspd_o = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/sdspd_o.csv").set_index("time")

# %%
df = pd.concat([dir_o,spd_o,gust_o,sddir_o,sdspd_o],axis =1).drop(columns=["Unnamed: 0"])
df
# Out:
#                        dir_o      spd_o     gust_o  sddir_o   sdspd_o
# time
# 2018-01-01 00:10:00.0  200.0   4.805559   6.666672     10.0  0.833334
# 2018-01-01 00:20:00.0  198.0   4.583337   6.138894      9.0  0.694445
# 2018-01-01 00:30:00.0  198.0   4.694448   7.472228     11.0  0.944445
# 2018-01-01 00:40:00.0  197.0   4.750004   6.833339     11.0  1.000001
# 2018-01-01 00:50:00.0  199.0   5.000004   7.333339     13.0  1.027779
# ...                      ...        ...        ...      ...       ...
# 2022-12-30 23:20:00.0  200.0  11.194453  18.916682     17.0  3.250003
# 2022-12-30 23:30:00.0  200.0  11.861121  19.222238     18.0  3.250003
# 2022-12-30 23:40:00.0  201.0  10.194453  17.666681     19.0  3.000002
# 2022-12-30 23:50:00.0  204.0  10.833342  17.777792     17.0  3.138891
# 2022-12-31 00:00:00.0  204.0   9.944452  15.805568     20.0  3.111114
#
# [262224 rows x 5 columns]

# %%
df.describe()
# Out:
#                dir_o          spd_o         gust_o        sddir_o  \
# count  262224.000000  262224.000000  262224.000000  262224.000000
# mean       16.143339     -29.365292     -27.535640    -112.030825
# std      1119.166231     305.806919     306.022652    1100.695539
# min     -9999.000000   -2777.502222   -2777.502222   -9999.000000
# 25%        45.000000       1.916668       2.888891       5.000000
# 50%       140.000000       4.166670       5.888894       8.000000
# 75%       217.000000       6.888894       9.416674      13.000000
# max       360.000000      19.611127      34.694472     102.000000
#
#              sdspd_o
# count  262224.000000
# mean      -33.217609
# std       305.362726
# min     -2777.502222
# 25%         0.361111
# 50%         0.611112
# 75%         1.000001
# max         6.111116

# %%
df[df<0] =np.NaN

# %%
df.describe()
# Out:
#                dir_o          spd_o         gust_o        sddir_o  \
# count  259014.000000  259017.000000  259017.000000  259014.000000
# mean      140.262538       4.660564       6.512870      10.499892
# std        97.846537       3.150436       4.178043       8.335541
# min         0.000000       0.000000       0.000000       0.000000
# 25%        46.000000       2.000002       3.000002       5.000000
# 50%       149.000000       4.222226       5.944449       9.000000
# 75%       217.000000       6.916672       9.472230      13.000000
# max       360.000000      19.611127      34.694472     102.000000
#
#              sdspd_o
# count  259017.000000
# mean        0.760550
# std         0.551481
# min         0.000000
# 25%         0.361111
# 50%         0.611112
# 75%         1.000001
# max         6.111116

# %%
df.index = pd.to_datetime(df.index)

# %%
df["dir_o"][:100].plot();

# %%
df
# Out:
#                      dir_o      spd_o     gust_o  sddir_o   sdspd_o
# time
# 2018-01-01 00:10:00  200.0   4.805559   6.666672     10.0  0.833334
# 2018-01-01 00:20:00  198.0   4.583337   6.138894      9.0  0.694445
# 2018-01-01 00:30:00  198.0   4.694448   7.472228     11.0  0.944445
# 2018-01-01 00:40:00  197.0   4.750004   6.833339     11.0  1.000001
# 2018-01-01 00:50:00  199.0   5.000004   7.333339     13.0  1.027779
# ...                    ...        ...        ...      ...       ...
# 2022-12-30 23:20:00  200.0  11.194453  18.916682     17.0  3.250003
# 2022-12-30 23:30:00  200.0  11.861121  19.222238     18.0  3.250003
# 2022-12-30 23:40:00  201.0  10.194453  17.666681     19.0  3.000002
# 2022-12-30 23:50:00  204.0  10.833342  17.777792     17.0  3.138891
# 2022-12-31 00:00:00  204.0   9.944452  15.805568     20.0  3.111114
#
# [262224 rows x 5 columns]

# %%
df["time"] =df.index

# %%
df
# Out:
#                      dir_o      spd_o     gust_o  sddir_o   sdspd_o
# time
# 2018-01-01 00:10:00  200.0   4.805559   6.666672     10.0  0.833334
# 2018-01-01 00:20:00  198.0   4.583337   6.138894      9.0  0.694445
# 2018-01-01 00:30:00  198.0   4.694448   7.472228     11.0  0.944445
# 2018-01-01 00:40:00  197.0   4.750004   6.833339     11.0  1.000001
# 2018-01-01 00:50:00  199.0   5.000004   7.333339     13.0  1.027779
# ...                    ...        ...        ...      ...       ...
# 2022-12-30 23:20:00  200.0  11.194453  18.916682     17.0  3.250003
# 2022-12-30 23:30:00  200.0  11.861121  19.222238     18.0  3.250003
# 2022-12-30 23:40:00  201.0  10.194453  17.666681     19.0  3.000002
# 2022-12-30 23:50:00  204.0  10.833342  17.777792     17.0  3.138891
# 2022-12-31 00:00:00  204.0   9.944452  15.805568     20.0  3.111114
#
# [262224 rows x 5 columns]

# %%
df.to_csv("station.csv")

# %%
pd.read_csv("/content/station.csv").set_index("time").describe()
# Out:
#                dir_o          spd_o         gust_o        sddir_o  \
# count  259014.000000  259017.000000  259017.000000  259014.000000
# mean      140.262538       4.660564       6.512870      10.499892
# std        97.846537       3.150436       4.178043       8.335541
# min         0.000000       0.000000       0.000000       0.000000
# 25%        46.000000       2.000002       3.000002       5.000000
# 50%       149.000000       4.222226       5.944449       9.000000
# 75%       217.000000       6.916672       9.472230      13.000000
# max       360.000000      19.611127      34.694472     102.000000
#
#              sdspd_o
# count  259017.000000
# mean        0.760550
# std         0.551481
# min         0.000000
# 25%         0.361111
# 50%         0.611112
# 75%         1.000001
# max         6.111116

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 262224 entries, 2018-01-01 00:10:00 to 2022-12-31 00:00:00
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   dir_o    259014 non-null  float64
#  1   spd_o    259017 non-null  float64
#  2   gust_o   259017 non-null  float64
#  3   sddir_o  259014 non-null  float64
#  4   sdspd_o  259017 non-null  float64
# dtypes: float64(5)
# memory usage: 12.0 MB

# %%
import pandas as pd

df_2018 = pd.read_excel("/content/2018.xlsx")
df_2019 = pd.read_excel("/content/2019.xlsx")
df_2020 = pd.read_excel("/content/2020.xlsx")
df_2021 = pd.read_excel("/content/2021.xlsx")
df_2022 = pd.read_excel("/content/2022.xlsx")

# %%
df_prec =pd.concat([df_2018,df_2019,df_2020,df_2021,df_2022])
df_prec = df_prec.rename(columns={"Instante lectura": "time", "Chuvia": "prec_o"})

# %%
df_prec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262224 entries, 0 to 52415
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    262224 non-null  object
#  1   prec_o  262224 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 6.0+ MB

# %%
df_prec['time'] = pd.to_datetime(df_prec["time"])

# %%
df_prec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262224 entries, 0 to 52415
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    262224 non-null  datetime64[ns]
#  1   prec_o  262224 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.0 MB

# %%
df_prec.to_csv('/content/drive/MyDrive/Colab Notebooks/Coron/station_data/prec_o.csv', index=False)

# %%
df =pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/prec_o.csv",parse_dates=["time"]).set_index("time")

# %%
import numpy as np

df = df.mask(df < 0, np.nan)
df.plot()

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Coron/station_data/prec_o.csv', index=False)

# %%
df =pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/prec_o.csv",parse_dates=["time"]).describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-4c520250181a> in <module>
# ----> 1 df =pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/prec_o.csv",parse_dates=["time"]).describe()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df ["time"] = df.index

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Coron/station_data/prec_o.csv', index=False)

# %%
df.isna().sum().sum()
# Out:
# 3191

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 262224 entries, 2018-01-01 00:10:00 to 2022-12-31 00:00:00
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   prec_o  259033 non-null  float64
#  1   time    262224 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.0 MB

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Coron/station_data/prec_o.csv')
# Out:
#         prec_o                 time
# 0          0.0  2018-01-01 00:10:00
# 1          0.0  2018-01-01 00:20:00
# 2          0.0  2018-01-01 00:30:00
# 3          0.0  2018-01-01 00:40:00
# 4          0.0  2018-01-01 00:50:00
# ...        ...                  ...
# 262219     0.0  2022-12-30 23:20:00
# 262220     0.0  2022-12-30 23:30:00
# 262221     0.0  2022-12-30 23:40:00
# 262222     0.0  2022-12-30 23:50:00
# 262223     0.0  2022-12-31 00:00:00
#
# [262224 rows x 2 columns]
